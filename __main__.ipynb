# %%
from time import sleep
from current import current
from resistor import resistor
from temperature import temperature
from voltage import voltage
from utils import *
import pandas as pd

# %%
#센서정보 받아오기
def sensor():
    url = "http://115.145.159.149:8888"

    I = current(url)
    save_to_csv(I, columns=["Current(A)"], filename="results/current.csv")
    sleep(4)
    R = resistor(url)
    save_to_csv(R,  columns=["Current(A)", "Resistance(Ohm)"], filename="results/resistor.csv")
    sleep(4)
    T = temperature(url)
    save_to_csv(T,  columns=["Temperature(C)"], filename="results/temperature.csv")
    sleep(4)
    V = voltage(url)
    save_to_csv(V,  columns=["Input Voltage(V)", "Output Voltage(V)"], filename="results/voltage.csv")

if __name__ == "__main__":
    sensor()
# Out:
# [Info] Saved data to results/current.csv.
# [Info] Saved data to results/resistor.csv.
# [Info] Saved data to results/temperature.csv.
# [Info] Saved data to results/voltage.csv.

# %%
#인가전압 plot
file_path = r"D:\__________Workspace__________\sensor\results\current.csv"

input_current_data = pd.read_csv(file_path)
plot("Input Current plot", input_current_data, xlabel="samples", ylabel="values")

# %%
#인가전압 plot
file_path = r"D:\__________Workspace__________\sensor\results\voltage.csv"

out_current_data = pd.read_csv(file_path)
plot("Output Current plot", out_current_data, xlabel="samples", ylabel="values")

# %%
plot_with_local("Output Current plot", out_current_data, xlabel="samples", ylabel="values", threshold=500)
